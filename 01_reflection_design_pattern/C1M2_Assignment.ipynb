# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a asistant to write an complete essay
    Topic: {topic}
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Take a previously generated essay draft and provide critical but constructive feedback.
    Focus on structure, clarity, the strength of the central argument of the topic and explanation for deeper understanding
    draft:{draft}
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert editor. Your task is to rewrite and revised the provided essay draft.
    original_draft:{original_draft}
    to address all criticisms and suggestions found in the reflection notes.
    reflection:{reflection}
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Case for and Against Government Regulation of Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become an integral part of everyday life, influencing how we communicate, interact, and access information. Giants like Facebook, Twitter, Instagram, and TikTok hold immense power over public discourse, affecting everything from personal relationships to global politics. As the influence of social media continues to grow, debates on whether these platforms should be regulated by the government have intensified. This essay will explore the arguments for and against government regulation of social media platforms, ultimately highlighting the complexity of the issue.
#
# Arguments for Government Regulation
#
# 1. Combatting Misinformation and Fake News
#
# One of the strongest arguments in favor of government regulation is the need to combat misinformation and fake news. Social media platforms have been criticized for enabling the rapid spread of false information, which can have serious consequences for public health and safety, democratic processes, and social harmony. Government intervention could establish standards for information accuracy and accountability, helping to curb the proliferation of harmful misinformation.
#
# 2. Protecting User Privacy
#
# Social media platforms often collect and monetize vast amounts of user data, raising concerns about privacy. Regulation could enforce stricter data protection measures, ensuring that users have control over their personal information and are aware of how it is being used. This could be achieved through implementing comprehensive data protection laws like the European Union's General Data Protection Regulation (GDPR).
#
# 3. Preventing Harmful Content
#
# Another argument for regulation is the prevention of harmful content, including hate speech, cyberbullying, and extremist propaganda. Government oversight could lead to clearer guidelines and more consistent enforcement of content moderation. By setting specific legal standards, governments could help social media platforms create safer online environments.
#
# Arguments Against Government Regulation
#
# 1. Threat to Free Speech
#
# A major concern against government regulation is the potential threat to free speech. Social media is often seen as a platform for free expression, and governmental control could lead to censorship and suppression of dissenting voices. Regulations need to be carefully crafted to avoid impinging on individuals' rights to freedom of expression.
#
# 2. Innovation and Economic Impact
#
# Regulating social media platforms could stifle innovation and have negative economic consequences. Excessive regulation could hinder the growth of the tech industry and discourage startups, leading to decreased competition and innovation. The dynamic nature of technology requires flexible and adaptive policy-making to not impede progress.
#
# 3. Risk of Political Bias
#
# There is also the risk of political bias in regulation. Governments may impose regulations that serve their political interests, rather than the public interest. This could result in unfair practices, where certain viewpoints or political ideologies are favored over others, undermining the fundamental principles of democracy and equal representation.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government involves balancing the benefits of regulation with the potential drawbacks. While government oversight could address critical issues like misinformation, user privacy, and harmful content, it also raises concerns about free speech, economic impact, and political bias. As the digital landscape continues to evolve, finding the right approach to regulation will require careful consideration and collaboration between governments, tech companies, and civil society to ensure that social media serves the public interest without infringing on fundamental rights.
#
# 🧠 Feedback:
#
# Here’s a section‐by‐section review of your draft with concrete suggestions to tighten structure, sharpen your argument, and deepen your analysis.
#
# 1. Introduction
# • Strengths:
#   – You immediately situate the debate (“digital age,” “Giants like Facebook…”) and signal the tension (pros vs. cons).
#   – You preview your plan to explore both sides, which orients the reader.
# • Areas for improvement:
#   – Thesis clarity: Right now you say you’ll “explore” the arguments. Consider taking a clearer position or at least flagging the criteria you’ll use to decide which side carries more weight (public safety, free-speech values, market health, etc.).
#   – Context and definitions: Briefly define what you mean by “regulation” (e.g., antitrust action, content-moderation mandates, data-privacy laws). That will help you avoid ambiguity later.
#
# 2. Arguments for Regulation
# • Structure: You use numbered headings, which is fine for a draft, but in your final essay you might prefer thematic paragraphs with clear topic sentences rather than “1., 2., 3.”
# • Depth and evidence:
#   – Misinformation: You note “serious consequences,” but you could strengthen this point with a concrete example (e.g., the role of false rumors in the 2016 U.S. election or the spread of health misinformation during COVID-19). Cite a study or report if possible.
#   – Privacy: You invoke GDPR, which is great. To deepen, contrast GDPR with U.S. approaches (e.g., California’s CCPA) and show how enforcement or penalties differ.
#   – Harmful content: Rather than simply calling for “clearer guidelines,” you could discuss what “clear” looks like. Who draws the lines? How do platforms handle appeals? You might mention Facebook’s Oversight Board or Twitter’s evolving hate-speech policies.
#
# 3. Arguments Against Regulation
# • Balancing nuance: You list three broad objections, but they sometimes read like abstract bullet points. For each, ask yourself: under what circumstances would that risk actually materialize?
#   – Free speech: Acknowledge that private companies already exercise editorial control—and contrast that with government censorship. This shows you understand both sides.
#   – Innovation: You say “excessive regulation could stifle innovation,” but can you point to an industry or moment where that happened? Perhaps compare telecom regulation in the 1990s or EU digital-copyright rules.
#   – Political bias: Good point. You might mention specific allegations of bias (for instance, accusations of platform interference in elections) and then show what safeguards could limit that risk.
#
# 4. Organization and Transitions
# • Signposting: After finishing the “pros” section, insert a brief transitional paragraph: “While regulation promises certain benefits, critics argue that it may also carry serious costs…” This prepares the reader.
# • Grouping ideas: Instead of three short “arguments against,” you could group “free speech” and “political bias” under a larger category of “risks to democratic expression” and treat “innovation” as a separate economic concern.
#
# 5. Strength of Central Argument
# • Make your stance explicit. Even if you remain “balanced,” you can evaluate each argument against shared criteria—e.g., “Which risk is more pressing? Which solution is more feasible?”
# • Weigh trade-offs. For example, note that privacy regulation (like GDPR) coexists with vigorous tech growth in Europe—suggesting that “innovation vs. privacy” need not be a zero-sum game.
#
# 6. Clarity and Style
# • Topic sentences: Ensure each paragraph opens with a sentence that indicates precisely what you will argue and why it matters.
# • Avoid generalities: Words like “often,” “could,” or “might” are hedges. Where possible, replace them with concrete data or at least illustrative examples.
# • Concision: Some sentences repeat ideas (e.g., “social media platforms… influence how we communicate” appears twice). Read aloud to spot redundancies.
#
# 7. Conclusion
# • Beyond summary: Rather than just restating the pros and cons, use your conclusion to suggest next steps or principles for effective regulation—e.g., multi-stakeholder governance, periodic review of rules, technological audits, or sandbox environments for testing policies.
# • Call to action: If appropriate, close with a challenge to policymakers, platforms, and citizens to collaborate in designing fair, adaptable rules.
#
# —Overall, your draft lays out the core dimensions of the debate; now you can make it more compelling by sharpening your thesis, weaving in real-world examples and data, and carefully signaling connections between ideas. That added specificity will elevate your essay from a survey of arguments to a nuanced, persuasive analysis.
# ✍️ Revised:
#
# Title: Navigating the Complex Terrain of Government Regulation on Social Media Platforms
#
# Introduction
#
# In today's digital era, social media platforms are pivotal in shaping communication, interaction, and information access. Behemoths like Facebook, Twitter, Instagram, and TikTok wield significant influence over public discourse, impacting personal relationships and global politics. As their sway continues to expand, the debate over whether governments should regulate these platforms has gained momentum. This essay will analyze the arguments advocating for and opposing government regulation of social media, considering factors like public safety, free speech, and market health, to underscore the multifaceted nature of this issue.
#
# Defining Regulation
#
# Before delving into the arguments, it's crucial to clarify what is meant by "regulation" in this context. Regulation can encompass antitrust actions, content-moderation mandates, and data-privacy laws, each with distinct implications for how social media platforms operate.
#
# Arguments for Government Regulation
#
# Combatting Misinformation and Fake News
#
# A compelling argument for government regulation is the need to address misinformation and fake news. Social media platforms have been criticized for facilitating the rapid dissemination of false information, with dire consequences for public health, democratic processes, and social harmony. For instance, the spread of false rumors during the 2016 U.S. election and misinformation during the COVID-19 pandemic underscore the urgent need for standards of information accuracy and accountability. Government intervention could help curb the proliferation of harmful misinformation by establishing these standards.
#
# Protecting User Privacy
#
# The vast collection and monetization of user data by social media platforms raise significant privacy concerns. Regulation could enforce stricter data protection measures, empowering users with control over their personal information and transparency about its use. The European Union's General Data Protection Regulation (GDPR) serves as a model, contrasting with more lenient U.S. approaches like California’s Consumer Privacy Act (CCPA). Highlighting these differences can illustrate how regulation might be implemented and enforced.
#
# Preventing Harmful Content
#
# Regulating social media platforms could also prevent the spread of harmful content, such as hate speech, cyberbullying, and extremist propaganda. Government oversight might lead to clearer guidelines and more consistent content moderation enforcement. Platforms could adopt frameworks similar to Facebook's Oversight Board or Twitter's evolving hate-speech policies to ensure safer online environments.
#
# Arguments Against Government Regulation
#
# Risks to Democratic Expression
#
# One significant concern about government regulation is the potential threat to free speech and democratic expression. Social media is seen as a bastion of free expression, but governmental control could lead to censorship and suppression of dissenting voices. While private companies already exercise editorial control, distinguishing this from government censorship is crucial. Regulations must be carefully crafted to avoid infringing on individuals' freedom of expression.
#
# Innovation and Economic Impact
#
# Another argument against regulation is the potential stifling of innovation and negative economic consequences. Excessive regulation could hinder tech industry growth and discourage startups, reducing competition and innovation. Historical examples, like telecom regulation in the 1990s or EU digital-copyright rules, highlight how regulation might impede technological progress.
#
# Political Bias
#
# The risk of political bias in regulation is another concern. Governments may impose regulations that serve political interests rather than the public good, resulting in unfair practices that favor specific viewpoints or ideologies. Safeguards must be implemented to limit this risk, ensuring regulations uphold democratic principles and equal representation.
#
# Conclusion
#
# The question of whether governments should regulate social media platforms involves balancing the potential benefits of regulation with its drawbacks. While oversight might address critical issues like misinformation, user privacy, and harmful content, it also raises concerns about free speech, economic impacts, and political bias. As the digital landscape evolves, finding the right regulatory approach will require careful consideration and collaboration among governments, tech companies, and civil society. This cooperation is essential to ensure social media platforms serve the public interest without infringing on fundamental rights. Moving forward, stakeholders must work together to design regulations that are fair, adaptable, and reflective of the rapidly changing technological environment.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for and Against Government Regulation of Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become an integral part of everyday life, influencing how we communicate, interact, and access information. Giants like Facebook, Twitter, Instagram, and TikTok hold immense power over public discourse, affecting everything from personal relationships to global politics. As the influence of social media continues to grow, debates on whether these platforms should be regulated by the government have intensified. This essay will explore the arguments for and against government regulation of social media platforms, ultimately highlighting the complexity of the issue.
#
# Arguments for Government Regulation
#
# 1. Combatting Misinformation and Fake News
#
# One of the strongest arguments in favor of government regulation is the need to combat misinformation and fake news. Social media platforms have been criticized for enabling the rapid spread of false information, which can have serious consequences for public health and safety, democratic processes, and social harmony. Government intervention could establish standards for information accuracy and accountability, helping to curb the proliferation of harmful misinformation.
#
# 2. Protecting User Privacy
#
# Social media platforms often collect and monetize vast amounts of user data, raising concerns about privacy. Regulation could enforce stricter data protection measures, ensuring that users have control over their personal information and are aware of how it is being used. This could be achieved through implementing comprehensive data protection laws like the European Union's General Data Protection Regulation (GDPR).
#
# 3. Preventing Harmful Content
#
# Another argument for regulation is the prevention of harmful content, including hate speech, cyberbullying, and extremist propaganda. Government oversight could lead to clearer guidelines and more consistent enforcement of content moderation. By setting specific legal standards, governments could help social media platforms create safer online environments.
#
# Arguments Against Government Regulation
#
# 1. Threat to Free Speech
#
# A major concern against government regulation is the potential threat to free speech. Social media is often seen as a platform for free expression, and governmental control could lead to censorship and suppression of dissenting voices. Regulations need to be carefully crafted to avoid impinging on individuals' rights to freedom of expression.
#
# 2. Innovation and Economic Impact
#
# Regulating social media platforms could stifle innovation and have negative economic consequences. Excessive regulation could hinder the growth of the tech industry and discourage startups, leading to decreased competition and innovation. The dynamic nature of technology requires flexible and adaptive policy-making to not impede progress.
#
# 3. Risk of Political Bias
#
# There is also the risk of political bias in regulation. Governments may impose regulations that serve their political interests, rather than the public interest. This could result in unfair practices, where certain viewpoints or political ideologies are favored over others, undermining the fundamental principles of democracy and equal representation.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government involves balancing the benefits of regulation with the potential drawbacks. While government oversight could address critical issues like misinformation, user privacy, and harmful content, it also raises concerns about free speech, economic impact, and political bias. As the digital landscape continues to evolve, finding the right approach to regulation will require careful consideration and collaboration between governments, tech companies, and civil society to ensure that social media serves the public interest without infringing on fundamental rights.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a section‐by‐section review of your draft with concrete suggestions to tighten structure, sharpen your argument, and deepen your analysis.
#
# 1. Introduction
# • Strengths:
#   – You immediately situate the debate (“digital age,” “Giants like Facebook…”) and signal the tension (pros vs. cons).
#   – You preview your plan to explore both sides, which orients the reader.
# • Areas for improvement:
#   – Thesis clarity: Right now you say you’ll “explore” the arguments. Consider taking a clearer position or at least flagging the criteria you’ll use to decide which side carries more weight (public safety, free-speech values, market health, etc.).
#   – Context and definitions: Briefly define what you mean by “regulation” (e.g., antitrust action, content-moderation mandates, data-privacy laws). That will help you avoid ambiguity later.
#
# 2. Arguments for Regulation
# • Structure: You use numbered headings, which is fine for a draft, but in your final essay you might prefer thematic paragraphs with clear topic sentences rather than “1., 2., 3.”
# • Depth and evidence:
#   – Misinformation: You note “serious consequences,” but you could strengthen this point with a concrete example (e.g., the role of false rumors in the 2016 U.S. election or the spread of health misinformation during COVID-19). Cite a study or report if possible.
#   – Privacy: You invoke GDPR, which is great. To deepen, contrast GDPR with U.S. approaches (e.g., California’s CCPA) and show how enforcement or penalties differ.
#   – Harmful content: Rather than simply calling for “clearer guidelines,” you could discuss what “clear” looks like. Who draws the lines? How do platforms handle appeals? You might mention Facebook’s Oversight Board or Twitter’s evolving hate-speech policies.
#
# 3. Arguments Against Regulation
# • Balancing nuance: You list three broad objections, but they sometimes read like abstract bullet points. For each, ask yourself: under what circumstances would that risk actually materialize?
#   – Free speech: Acknowledge that private companies already exercise editorial control—and contrast that with government censorship. This shows you understand both sides.
#   – Innovation: You say “excessive regulation could stifle innovation,” but can you point to an industry or moment where that happened? Perhaps compare telecom regulation in the 1990s or EU digital-copyright rules.
#   – Political bias: Good point. You might mention specific allegations of bias (for instance, accusations of platform interference in elections) and then show what safeguards could limit that risk.
#
# 4. Organization and Transitions
# • Signposting: After finishing the “pros” section, insert a brief transitional paragraph: “While regulation promises certain benefits, critics argue that it may also carry serious costs…” This prepares the reader.
# • Grouping ideas: Instead of three short “arguments against,” you could group “free speech” and “political bias” under a larger category of “risks to democratic expression” and treat “innovation” as a separate economic concern.
#
# 5. Strength of Central Argument
# • Make your stance explicit. Even if you remain “balanced,” you can evaluate each argument against shared criteria—e.g., “Which risk is more pressing? Which solution is more feasible?”
# • Weigh trade-offs. For example, note that privacy regulation (like GDPR) coexists with vigorous tech growth in Europe—suggesting that “innovation vs. privacy” need not be a zero-sum game.
#
# 6. Clarity and Style
# • Topic sentences: Ensure each paragraph opens with a sentence that indicates precisely what you will argue and why it matters.
# • Avoid generalities: Words like “often,” “could,” or “might” are hedges. Where possible, replace them with concrete data or at least illustrative examples.
# • Concision: Some sentences repeat ideas (e.g., “social media platforms… influence how we communicate” appears twice). Read aloud to spot redundancies.
#
# 7. Conclusion
# • Beyond summary: Rather than just restating the pros and cons, use your conclusion to suggest next steps or principles for effective regulation—e.g., multi-stakeholder governance, periodic review of rules, technological audits, or sandbox environments for testing policies.
# • Call to action: If appropriate, close with a challenge to policymakers, platforms, and citizens to collaborate in designing fair, adaptable rules.
#
# —Overall, your draft lays out the core dimensions of the debate; now you can make it more compelling by sharpening your thesis, weaving in real-world examples and data, and carefully signaling connections between ideas. That added specificity will elevate your essay from a survey of arguments to a nuanced, persuasive analysis.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Complex Terrain of Government Regulation on Social Media Platforms
#
# Introduction
#
# In today's digital era, social media platforms are pivotal in shaping communication, interaction, and information access. Behemoths like Facebook, Twitter, Instagram, and TikTok wield significant influence over public discourse, impacting personal relationships and global politics. As their sway continues to expand, the debate over whether governments should regulate these platforms has gained momentum. This essay will analyze the arguments advocating for and opposing government regulation of social media, considering factors like public safety, free speech, and market health, to underscore the multifaceted nature of this issue.
#
# Defining Regulation
#
# Before delving into the arguments, it's crucial to clarify what is meant by "regulation" in this context. Regulation can encompass antitrust actions, content-moderation mandates, and data-privacy laws, each with distinct implications for how social media platforms operate.
#
# Arguments for Government Regulation
#
# Combatting Misinformation and Fake News
#
# A compelling argument for government regulation is the need to address misinformation and fake news. Social media platforms have been criticized for facilitating the rapid dissemination of false information, with dire consequences for public health, democratic processes, and social harmony. For instance, the spread of false rumors during the 2016 U.S. election and misinformation during the COVID-19 pandemic underscore the urgent need for standards of information accuracy and accountability. Government intervention could help curb the proliferation of harmful misinformation by establishing these standards.
#
# Protecting User Privacy
#
# The vast collection and monetization of user data by social media platforms raise significant privacy concerns. Regulation could enforce stricter data protection measures, empowering users with control over their personal information and transparency about its use. The European Union's General Data Protection Regulation (GDPR) serves as a model, contrasting with more lenient U.S. approaches like California’s Consumer Privacy Act (CCPA). Highlighting these differences can illustrate how regulation might be implemented and enforced.
#
# Preventing Harmful Content
#
# Regulating social media platforms could also prevent the spread of harmful content, such as hate speech, cyberbullying, and extremist propaganda. Government oversight might lead to clearer guidelines and more consistent content moderation enforcement. Platforms could adopt frameworks similar to Facebook's Oversight Board or Twitter's evolving hate-speech policies to ensure safer online environments.
#
# Arguments Against Government Regulation
#
# Risks to Democratic Expression
#
# One significant concern about government regulation is the potential threat to free speech and democratic expression. Social media is seen as a bastion of free expression, but governmental control could lead to censorship and suppression of dissenting voices. While private companies already exercise editorial control, distinguishing this from government censorship is crucial. Regulations must be carefully crafted to avoid infringing on individuals' freedom of expression.
#
# Innovation and Economic Impact
#
# Another argument against regulation is the potential stifling of innovation and negative economic consequences. Excessive regulation could hinder tech industry growth and discourage startups, reducing competition and innovation. Historical examples, like telecom regulation in the 1990s or EU digital-copyright rules, highlight how regulation might impede technological progress.
#
# Political Bias
#
# The risk of political bias in regulation is another concern. Governments may impose regulations that serve political interests rather than the public good, resulting in unfair practices that favor specific viewpoints or ideologies. Safeguards must be implemented to limit this risk, ensuring regulations uphold democratic principles and equal representation.
#
# Conclusion
#
# The question of whether governments should regulate social media platforms involves balancing the potential benefits of regulation with its drawbacks. While oversight might address critical issues like misinformation, user privacy, and harmful content, it also raises concerns about free speech, economic impacts, and political bias. As the digital landscape evolves, finding the right regulatory approach will require careful consideration and collaboration among governments, tech companies, and civil society. This cooperation is essential to ensure social media platforms serve the public interest without infringing on fundamental rights. Moving forward, stakeholders must work together to design regulations that are fair, adaptable, and reflective of the rapidly changing technological environment.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
